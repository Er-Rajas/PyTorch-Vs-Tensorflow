# %% [markdown]
# # Model Building using Tensorflow GPU

# %%
import pandas as pd
import numpy as np
import tensorflow as tf
import random
from sklearn.preprocessing import MinMaxScaler
import matplotlib.pyplot as plt
import seaborn as sns
from joblib import dump,load
import os
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score
import time
import GPUtil
import psutil
import re

# %%
seed = 42
os.environ['PYTHONHASHSEED'] = str(seed)
os.environ['TF_DETERMINISTIC_OPS'] = '1'
os.environ['TF_CUDNN_DETERMINISTIC'] = '1'

random.seed(seed)
np.random.seed(seed)
tf.random.set_seed(seed)

# Ensure no extra parallel threads cause nondeterminism
tf.config.threading.set_inter_op_parallelism_threads(4)
tf.config.threading.set_intra_op_parallelism_threads(4)

# %%
print("TensorFlow version:", tf.__version__)
print("GPUs Available:", tf.config.list_physical_devices('GPU'))
# Out:
# TensorFlow version: 2.9.0
# GPUs Available: [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]

# %%
gpus = tf.config.experimental.list_physical_devices('GPU')
if gpus:
    try:
        for gpu in gpus:
            tf.config.experimental.set_memory_growth(gpu, True)
            tf.config.experimental.set_visible_devices(gpus[0], 'GPU')
        
        
    except RuntimeError as e:
        print(e)

# %%
tf.keras.backend.clear_session()

# %%
df = pd.read_csv(r"../data/simulated_train.csv")

# %%
def smart_fill_temp(series):
    series = series.copy()
    for idx in series[series.isna()].index:
       
        next_vals = series[idx+1:idx+10].dropna().values[:2]
        if len(next_vals) > 0:
            avg_val = round(np.mean(next_vals))
            series.loc[idx] = avg_val
    return series

df['TEMP_30MIN_AGO'] = smart_fill_temp(df['TEMP_30MIN_AGO'].astype(float))

df['IRR_15MIN_AGO']= df['IRR_15MIN_AGO'].fillna(0.0)

# %% [markdown]
# ## MLP Baseline model

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout,ReLU
from tensorflow.keras.callbacks import EarlyStopping
import tensorflow as tf

# %%
df_mlp = df.copy()

# %%
df_mlp= df_mlp.drop(columns=['DATE_TIME','HOUR','MINUTE'])

# %%
df_mlp.columns
# Out:
# Index(['AMBIENT_TEMPERATURE', 'IRRADIATION', 'DC_POWER', 'HOUR_SIN',
#        'HOUR_COS', 'IS_NIGHT', 'DAWN_DUSK', 'DC_PER_IRR', 'IRR_15MIN_AGO',
#        'TEMP_30MIN_AGO', 'DAY_OF_WEEK', 'IS_WEEKEND'],
#       dtype='object')

# %%
features = ['AMBIENT_TEMPERATURE', 'IRRADIATION', 'DC_PER_IRR',
       'HOUR_SIN', 'HOUR_COS', 'IS_NIGHT', 'DAWN_DUSK', 
       'IRR_15MIN_AGO', 'TEMP_30MIN_AGO', 'DAY_OF_WEEK', 'IS_WEEKEND']
target = ['DC_POWER']
scale = ['AMBIENT_TEMPERATURE', 'IRRADIATION', 'DC_PER_IRR','IRR_15MIN_AGO', 'TEMP_30MIN_AGO']

# %%
X_to_scale = df_mlp[scale]
X_rest = df_mlp[[col for col in features if col not in scale]]

scaler_x = MinMaxScaler()
X_scaled = pd.DataFrame(scaler_x.fit_transform(X_to_scale), columns=scale, index=df_mlp.index)

X = pd.concat([X_scaled, X_rest], axis=1)[features]

# %%
dump(scaler_x,'../model/mlp_x_scaler.joblib')
# Out:
# ['../model/mlp_x_scaler.joblib']

# %%
y = df_mlp[target]

scaler_y = MinMaxScaler()
y_scaled = pd.DataFrame(scaler_y.fit_transform(y),columns=target,index=df_mlp.index)
y = y_scaled

# %%
dump(scaler_y,'../model/mlp_y_scaler.joblib')
# Out:
# ['../model/mlp_y_scaler.joblib']

# %%
train_size = int(len(X) * 0.8)
X_train, X_val = X[:train_size], X[train_size:]
y_train, y_val = y[:train_size], y[train_size:]

# %%
model = Sequential([
    Dense(128, activation='relu', input_shape=(X_train.shape[1],)),
    Dense(64, activation='relu'),
    Dense(32, activation='relu'),
    Dense(1)
])
model.compile(optimizer='adam',loss='mae',metrics=['mse'])

# %%
class TimeResourceCallback(tf.keras.callbacks.Callback):
    def on_train_begin(self, logs=None):
        self.epoch_times = []
        self.gpu_memory = []
        self.cpu_memory = []

    def on_epoch_begin(self, epoch, logs=None):
        self.start_time = time.time()

    def on_epoch_end(self, epoch, logs=None):
        # record time
        self.epoch_times.append(time.time() - self.start_time)

        # check GPU
        gpus = GPUtil.getGPUs()
        if gpus:  # GPU mode
            self.gpu_memory.append(gpus[0].memoryUsed)  # in MB
            self.cpu_memory.append(None)
        else:  # CPU mode
            mem = psutil.virtual_memory().used / (1024 ** 2)  # in MB
            self.cpu_memory.append(mem)
            self.gpu_memory.append(None)

# %%
# early_stop = EarlyStopping(patience=2,verbose=1),callbacks=[early_stop]
start = time.time()
time_res_cb = TimeResourceCallback()
with tf.device('/GPU:0'):
    history = model.fit(X_train,y_train,validation_data=(X_val, y_val),epochs=100,batch_size=64,shuffle=True,callbacks=[time_res_cb],verbose=1)
end = time.time()
train_time = end - start
# Out:
# Epoch 1/100
# 6/6 [==============================] - 3s 55ms/step - loss: 0.2304 - mse: 0.1195 - val_loss: 0.1404 - val_mse: 0.0453
# Epoch 2/100
# 6/6 [==============================] - 0s 20ms/step - loss: 0.1420 - mse: 0.0468 - val_loss: 0.0922 - val_mse: 0.0167
# Epoch 3/100
# 6/6 [==============================] - 0s 20ms/step - loss: 0.0851 - mse: 0.0144 - val_loss: 0.0996 - val_mse: 0.0214
# Epoch 4/100
# 6/6 [==============================] - 0s 20ms/step - loss: 0.0634 - mse: 0.0080 - val_loss: 0.0696 - val_mse: 0.0075
# Epoch 5/100
# 6/6 [==============================] - 0s 20ms/step - loss: 0.0477 - mse: 0.0046 - val_loss: 0.0482 - val_mse: 0.0045
# Epoch 6/100
# 6/6 [==============================] - 0s 17ms/step - loss: 0.0342 - mse: 0.0024 - val_loss: 0.0474 - val_mse: 0.0049
# Epoch 7/100
# 6/6 [==============================] - 0s 17ms/step - loss: 0.0242 - mse: 0.0011 - val_loss: 0.0556 - val_mse: 0.0054
# Epoch 8/100
# 6/6 [==============================] - 0s 17ms/step - loss: 0.0223 - mse: 8.1579e-04 - val_loss: 0.0478 - val_mse: 0.0037
# Epoch 9/100
# 6/6 [==============================] - 0s 20ms/step - loss: 0.0191 - mse: 6.8157e-04 - val_loss: 0.0373 - val_mse: 0.0032
# Epoch 10/100
# 6/6 [==============================] - 0s 17ms/step - loss: 0.0154 - mse: 4.3977e-04 - val_loss: 0.0382 - val_mse: 0.0030
# Epoch 11/100
# 6/6 [==============================] - 0s 17ms/step - loss: 0.0145 - mse: 3.6634e-04 - val_loss: 0.0410 - val_mse: 0.0028
# Epoch 12/100
# 6/6 [==============================] - 0s 17ms/step - loss: 0.0136 - mse: 3.5004e-04 - val_loss: 0.0477 - val_mse: 0.0032
# Epoch 13/100
# 6/6 [==============================] - 0s 17ms/step - loss: 0.0161 - mse: 4.4706e-04 - val_loss: 0.0377 - val_mse: 0.0024
# Epoch 14/100
# 6/6 [==============================] - 0s 19ms/step - loss: 0.0153 - mse: 4.2299e-04 - val_loss: 0.0240 - val_mse: 0.0013
# Epoch 15/100
# 6/6 [==============================] - 0s 17ms/step - loss: 0.0143 - mse: 4.0266e-04 - val_loss: 0.0284 - val_mse: 0.0016
# Epoch 16/100
# 6/6 [==============================] - 0s 20ms/step - loss: 0.0116 - mse: 2.7171e-04 - val_loss: 0.0274 - val_mse: 0.0018
# Epoch 17/100
# 6/6 [==============================] - 0s 17ms/step - loss: 0.0106 - mse: 2.1796e-04 - val_loss: 0.0354 - val_mse: 0.0022
# Epoch 18/100
# 6/6 [==============================] - 0s 17ms/step - loss: 0.0104 - mse: 2.0512e-04 - val_loss: 0.0305 - val_mse: 0.0019
# Epoch 19/100
# 6/6 [==============================] - 0s 18ms/step - loss: 0.0099 - mse: 1.9567e-04 - val_loss: 0.0339 - val_mse: 0.0021
# Epoch 20/100
# 6/6 [==============================] - 0s 17ms/step - loss: 0.0106 - mse: 2.0454e-04 - val_loss: 0.0260 - val_mse: 0.0015
# Epoch 21/100
# 6/6 [==============================] - 0s 21ms/step - loss: 0.0129 - mse: 3.0109e-04 - val_loss: 0.0306 - val_mse: 0.0015
# Epoch 22/100
# 6/6 [==============================] - 0s 17ms/step - loss: 0.0090 - mse: 1.5913e-04 - val_loss: 0.0418 - val_mse: 0.0027
# Epoch 23/100
# 6/6 [==============================] - 0s 17ms/step - loss: 0.0150 - mse: 3.7373e-04 - val_loss: 0.0374 - val_mse: 0.0022
# Epoch 24/100
# 6/6 [==============================] - 0s 17ms/step - loss: 0.0131 - mse: 3.1903e-04 - val_loss: 0.0266 - val_mse: 0.0016
# Epoch 25/100
# 6/6 [==============================] - 0s 20ms/step - loss: 0.0142 - mse: 3.1300e-04 - val_loss: 0.0207 - val_mse: 9.9542e-04
# Epoch 26/100
# 6/6 [==============================] - 0s 17ms/step - loss: 0.0101 - mse: 2.0346e-04 - val_loss: 0.0238 - val_mse: 0.0010
# Epoch 27/100
# 6/6 [==============================] - 0s 17ms/step - loss: 0.0091 - mse: 1.7029e-04 - val_loss: 0.0179 - val_mse: 6.9735e-04
# Epoch 28/100
# 6/6 [==============================] - 0s 19ms/step - loss: 0.0097 - mse: 1.7318e-04 - val_loss: 0.0272 - val_mse: 0.0015
# Epoch 29/100
# 6/6 [==============================] - 0s 20ms/step - loss: 0.0080 - mse: 1.2883e-04 - val_loss: 0.0258 - val_mse: 0.0014
# Epoch 30/100
# 6/6 [==============================] - 0s 20ms/step - loss: 0.0082 - mse: 1.2547e-04 - val_loss: 0.0298 - val_mse: 0.0016
# Epoch 31/100
# 6/6 [==============================] - 0s 20ms/step - loss: 0.0104 - mse: 1.8710e-04 - val_loss: 0.0207 - val_mse: 0.0011
# Epoch 32/100
# 6/6 [==============================] - 0s 20ms/step - loss: 0.0123 - mse: 2.8887e-04 - val_loss: 0.0153 - val_mse: 5.8504e-04
# Epoch 33/100
# 6/6 [==============================] - 0s 20ms/step - loss: 0.0151 - mse: 3.6750e-04 - val_loss: 0.0230 - val_mse: 0.0011
# Epoch 34/100
# 6/6 [==============================] - 0s 19ms/step - loss: 0.0181 - mse: 6.0729e-04 - val_loss: 0.0204 - val_mse: 8.1305e-04
# Epoch 35/100
# 6/6 [==============================] - 0s 20ms/step - loss: 0.0163 - mse: 4.2606e-04 - val_loss: 0.0203 - val_mse: 8.7278e-04
# Epoch 36/100
# 6/6 [==============================] - 0s 24ms/step - loss: 0.0100 - mse: 1.8291e-04 - val_loss: 0.0302 - val_mse: 0.0017
# Epoch 37/100
# 6/6 [==============================] - 0s 24ms/step - loss: 0.0082 - mse: 1.1598e-04 - val_loss: 0.0211 - val_mse: 0.0011
# Epoch 38/100
# 6/6 [==============================] - 0s 20ms/step - loss: 0.0073 - mse: 1.0735e-04 - val_loss: 0.0225 - val_mse: 9.8231e-04
# Epoch 39/100
# 6/6 [==============================] - 0s 20ms/step - loss: 0.0074 - mse: 1.1088e-04 - val_loss: 0.0249 - val_mse: 0.0011
# Epoch 40/100
# 6/6 [==============================] - 0s 20ms/step - loss: 0.0086 - mse: 1.3099e-04 - val_loss: 0.0254 - val_mse: 0.0011
# Epoch 41/100
# 6/6 [==============================] - 0s 19ms/step - loss: 0.0080 - mse: 1.1743e-04 - val_loss: 0.0204 - val_mse: 7.9944e-04
# Epoch 42/100
# 6/6 [==============================] - 0s 20ms/step - loss: 0.0092 - mse: 1.6565e-04 - val_loss: 0.0290 - val_mse: 0.0015
# Epoch 43/100
# 6/6 [==============================] - 0s 25ms/step - loss: 0.0096 - mse: 1.8194e-04 - val_loss: 0.0264 - val_mse: 0.0016
# Epoch 44/100
# 6/6 [==============================] - 0s 20ms/step - loss: 0.0092 - mse: 1.5604e-04 - val_loss: 0.0211 - val_mse: 0.0011
# Epoch 45/100
# 6/6 [==============================] - 0s 19ms/step - loss: 0.0074 - mse: 1.1342e-04 - val_loss: 0.0254 - val_mse: 0.0012
# Epoch 46/100
# 6/6 [==============================] - 0s 20ms/step - loss: 0.0082 - mse: 1.1440e-04 - val_loss: 0.0216 - val_mse: 9.3866e-04
# Epoch 47/100
# 6/6 [==============================] - 0s 20ms/step - loss: 0.0076 - mse: 1.2042e-04 - val_loss: 0.0262 - val_mse: 0.0012
# Epoch 48/100
# 6/6 [==============================] - 0s 20ms/step - loss: 0.0079 - mse: 1.0510e-04 - val_loss: 0.0260 - val_mse: 0.0013
# Epoch 49/100
# 6/6 [==============================] - 0s 20ms/step - loss: 0.0126 - mse: 3.0966e-04 - val_loss: 0.0287 - val_mse: 0.0016
# Epoch 50/100
# 6/6 [==============================] - 0s 20ms/step - loss: 0.0109 - mse: 1.9034e-04 - val_loss: 0.0172 - val_mse: 7.2959e-04
# Epoch 51/100
# 6/6 [==============================] - 0s 20ms/step - loss: 0.0097 - mse: 1.7015e-04 - val_loss: 0.0235 - val_mse: 0.0011
# Epoch 52/100
# 6/6 [==============================] - 0s 20ms/step - loss: 0.0085 - mse: 1.3773e-04 - val_loss: 0.0186 - val_mse: 7.2603e-04
# Epoch 53/100
# 6/6 [==============================] - 0s 20ms/step - loss: 0.0077 - mse: 1.0989e-04 - val_loss: 0.0196 - val_mse: 9.5137e-04
# Epoch 54/100
# 6/6 [==============================] - 0s 20ms/step - loss: 0.0072 - mse: 9.3044e-05 - val_loss: 0.0236 - val_mse: 0.0011
# Epoch 55/100
# 6/6 [==============================] - 0s 19ms/step - loss: 0.0067 - mse: 8.5052e-05 - val_loss: 0.0257 - val_mse: 0.0013
# Epoch 56/100
# 6/6 [==============================] - 0s 20ms/step - loss: 0.0061 - mse: 7.6907e-05 - val_loss: 0.0230 - val_mse: 0.0012
# Epoch 57/100
# 6/6 [==============================] - 0s 20ms/step - loss: 0.0060 - mse: 7.1522e-05 - val_loss: 0.0176 - val_mse: 7.6075e-04
# Epoch 58/100
# 6/6 [==============================] - 0s 20ms/step - loss: 0.0089 - mse: 1.4020e-04 - val_loss: 0.0224 - val_mse: 8.1328e-04
# Epoch 59/100
# 6/6 [==============================] - 0s 20ms/step - loss: 0.0098 - mse: 1.5245e-04 - val_loss: 0.0242 - val_mse: 0.0011
# Epoch 60/100
# 6/6 [==============================] - 0s 20ms/step - loss: 0.0123 - mse: 2.4575e-04 - val_loss: 0.0238 - val_mse: 0.0012
# Epoch 61/100
# 6/6 [==============================] - 0s 19ms/step - loss: 0.0113 - mse: 2.1563e-04 - val_loss: 0.0175 - val_mse: 6.5835e-04
# Epoch 62/100
# 6/6 [==============================] - 0s 20ms/step - loss: 0.0109 - mse: 2.0881e-04 - val_loss: 0.0170 - val_mse: 5.2649e-04
# Epoch 63/100
# 6/6 [==============================] - 0s 20ms/step - loss: 0.0105 - mse: 1.9088e-04 - val_loss: 0.0276 - val_mse: 0.0015
# Epoch 64/100
# 6/6 [==============================] - 0s 19ms/step - loss: 0.0095 - mse: 1.8451e-04 - val_loss: 0.0237 - val_mse: 0.0011
# Epoch 65/100
# 6/6 [==============================] - 0s 20ms/step - loss: 0.0077 - mse: 1.1375e-04 - val_loss: 0.0245 - val_mse: 8.8785e-04
# Epoch 66/100
# 6/6 [==============================] - 0s 20ms/step - loss: 0.0095 - mse: 1.5876e-04 - val_loss: 0.0188 - val_mse: 6.0102e-04
# Epoch 67/100
# 6/6 [==============================] - 0s 20ms/step - loss: 0.0100 - mse: 1.9333e-04 - val_loss: 0.0221 - val_mse: 0.0011
# Epoch 68/100
# 6/6 [==============================] - 0s 19ms/step - loss: 0.0103 - mse: 1.7071e-04 - val_loss: 0.0228 - val_mse: 0.0010
# Epoch 69/100
# 6/6 [==============================] - 0s 20ms/step - loss: 0.0082 - mse: 1.2040e-04 - val_loss: 0.0191 - val_mse: 6.7550e-04
# Epoch 70/100
# 6/6 [==============================] - 0s 20ms/step - loss: 0.0068 - mse: 8.3659e-05 - val_loss: 0.0245 - val_mse: 9.5772e-04
# Epoch 71/100
# 6/6 [==============================] - 0s 20ms/step - loss: 0.0065 - mse: 7.5093e-05 - val_loss: 0.0158 - val_mse: 5.7625e-04
# Epoch 72/100
# 6/6 [==============================] - 0s 20ms/step - loss: 0.0112 - mse: 2.1773e-04 - val_loss: 0.0182 - val_mse: 7.8058e-04
# Epoch 73/100
# 6/6 [==============================] - 0s 20ms/step - loss: 0.0136 - mse: 3.2939e-04 - val_loss: 0.0191 - val_mse: 8.5293e-04
# Epoch 74/100
# 6/6 [==============================] - 0s 20ms/step - loss: 0.0137 - mse: 3.6434e-04 - val_loss: 0.0148 - val_mse: 4.7027e-04
# Epoch 75/100
# 6/6 [==============================] - 0s 20ms/step - loss: 0.0119 - mse: 2.2378e-04 - val_loss: 0.0169 - val_mse: 7.2459e-04
# Epoch 76/100
# 6/6 [==============================] - 0s 20ms/step - loss: 0.0099 - mse: 1.9776e-04 - val_loss: 0.0231 - val_mse: 0.0010
# Epoch 77/100
# 6/6 [==============================] - 0s 20ms/step - loss: 0.0074 - mse: 9.8899e-05 - val_loss: 0.0224 - val_mse: 8.7429e-04
# Epoch 78/100
# 6/6 [==============================] - 0s 20ms/step - loss: 0.0060 - mse: 6.7589e-05 - val_loss: 0.0180 - val_mse: 6.8717e-04
# Epoch 79/100
# 6/6 [==============================] - 0s 23ms/step - loss: 0.0068 - mse: 7.7923e-05 - val_loss: 0.0281 - val_mse: 0.0013
# Epoch 80/100
# 6/6 [==============================] - 0s 20ms/step - loss: 0.0074 - mse: 9.1961e-05 - val_loss: 0.0179 - val_mse: 7.1395e-04
# Epoch 81/100
# 6/6 [==============================] - 0s 20ms/step - loss: 0.0072 - mse: 8.7720e-05 - val_loss: 0.0198 - val_mse: 8.6470e-04
# Epoch 82/100
# 6/6 [==============================] - 0s 20ms/step - loss: 0.0066 - mse: 9.9307e-05 - val_loss: 0.0179 - val_mse: 6.2896e-04
# Epoch 83/100
# 6/6 [==============================] - 0s 19ms/step - loss: 0.0063 - mse: 8.1261e-05 - val_loss: 0.0206 - val_mse: 8.8612e-04
# Epoch 84/100
# 6/6 [==============================] - 0s 20ms/step - loss: 0.0061 - mse: 6.8181e-05 - val_loss: 0.0224 - val_mse: 9.0017e-04
# Epoch 85/100
# 6/6 [==============================] - 0s 20ms/step - loss: 0.0061 - mse: 7.4958e-05 - val_loss: 0.0151 - val_mse: 5.4895e-04
# Epoch 86/100
# 6/6 [==============================] - 0s 20ms/step - loss: 0.0064 - mse: 7.1692e-05 - val_loss: 0.0239 - val_mse: 9.9749e-04
# Epoch 87/100
# 6/6 [==============================] - 0s 20ms/step - loss: 0.0047 - mse: 4.8750e-05 - val_loss: 0.0192 - val_mse: 6.9617e-04
# Epoch 88/100
# 6/6 [==============================] - 0s 20ms/step - loss: 0.0041 - mse: 3.5626e-05 - val_loss: 0.0224 - val_mse: 8.5275e-04
# Epoch 89/100
# 6/6 [==============================] - 0s 20ms/step - loss: 0.0052 - mse: 5.3950e-05 - val_loss: 0.0163 - val_mse: 5.3468e-04
# Epoch 90/100
# 6/6 [==============================] - 0s 19ms/step - loss: 0.0060 - mse: 7.0356e-05 - val_loss: 0.0203 - val_mse: 7.0817e-04
# Epoch 91/100
# 6/6 [==============================] - 0s 19ms/step - loss: 0.0048 - mse: 4.5300e-05 - val_loss: 0.0236 - val_mse: 9.3878e-04
# Epoch 92/100
# 6/6 [==============================] - 0s 20ms/step - loss: 0.0057 - mse: 5.4540e-05 - val_loss: 0.0194 - val_mse: 7.2077e-04
# Epoch 93/100
# 6/6 [==============================] - 0s 19ms/step - loss: 0.0055 - mse: 5.4379e-05 - val_loss: 0.0210 - val_mse: 7.8893e-04
# Epoch 94/100
# 6/6 [==============================] - 0s 20ms/step - loss: 0.0049 - mse: 4.4251e-05 - val_loss: 0.0165 - val_mse: 5.4061e-04
# Epoch 95/100
# 6/6 [==============================] - 0s 19ms/step - loss: 0.0049 - mse: 4.5697e-05 - val_loss: 0.0184 - val_mse: 7.2736e-04
# Epoch 96/100
# 6/6 [==============================] - 0s 20ms/step - loss: 0.0051 - mse: 4.7707e-05 - val_loss: 0.0240 - val_mse: 9.4427e-04
# Epoch 97/100
# 6/6 [==============================] - 0s 19ms/step - loss: 0.0063 - mse: 7.1512e-05 - val_loss: 0.0194 - val_mse: 8.3126e-04
# Epoch 98/100
# 6/6 [==============================] - 0s 20ms/step - loss: 0.0054 - mse: 5.4608e-05 - val_loss: 0.0132 - val_mse: 4.4217e-04
# Epoch 99/100
# 6/6 [==============================] - 0s 20ms/step - loss: 0.0086 - mse: 1.1417e-04 - val_loss: 0.0239 - val_mse: 0.0011
# Epoch 100/100
# 6/6 [==============================] - 0s 20ms/step - loss: 0.0069 - mse: 8.2591e-05 - val_loss: 0.0203 - val_mse: 7.9831e-04

# %%
epochs = range(1, len(time_res_cb.epoch_times) + 1)

fig, ax1 = plt.subplots()

# Epoch time
ax1.set_xlabel('Epoch')
ax1.set_ylabel('Time (s)', color='tab:blue')
ax1.plot(epochs, time_res_cb.epoch_times, color='tab:blue', marker='o', label="Time per epoch")
ax1.tick_params(axis='y', labelcolor='tab:blue')

# Resource usage
ax2 = ax1.twinx()
ax2.set_ylabel('Memory (MB)', color='tab:red')

if any(time_res_cb.gpu_memory):
    ax2.plot(epochs, time_res_cb.gpu_memory, color='tab:red', marker='x', label="GPU Memory")
else:
    ax2.plot(epochs, time_res_cb.cpu_memory, color='tab:green', marker='x', label="CPU Memory")

ax2.tick_params(axis='y', labelcolor='tab:red')
plt.title("Training Time & Resource Usage per Epoch (TF-MLP-GPU)")
fig.tight_layout()
plt.show()

# %%
y_pred_scaled = np.clip(model.predict(X_val), 0, None) 
y_pred = scaler_y.inverse_transform(y_pred_scaled)
y_val_inv = scaler_y.inverse_transform(y_val)


print(f"MAE: {mean_absolute_error(y_val_inv, y_pred):.4f}")
print(f"RMSE: {np.sqrt(mean_squared_error(y_val_inv, y_pred)):.4f}")
print(f"R²: {r2_score(y_val_inv, y_pred):.4f}")
print(f"Training time: {train_time:.2f} seconds")
# Out:
# 3/3 [==============================] - 0s 3ms/step
# MAE: 0.4218
# RMSE: 0.5953
# R²: 0.9925
# Training time: 13.65 seconds

# %%
plt.figure(figsize=(8,6))
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title('Learning Curve (TF-MLP-GPU)')
plt.legend()
plt.show()

# %%
plt.figure(figsize=(12, 6))
plt.plot(y_val_inv, label='Actual', alpha=0.7)
plt.plot(y_pred, label='Predicted', alpha=0.7)
plt.title('Actual vs Predicted DC Power (TF-MLP-GPU)', fontsize=14)
plt.xlabel('Samples')
plt.ylabel('DC Power (Original Scale)')
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
r2 = r2_score(y_val_inv, y_pred)

plt.figure(figsize=(8, 6))
sns.regplot(x=y_val_inv.flatten(), y=y_pred.flatten(), scatter_kws={"alpha":0.5, "s": 20}, line_kws={"color":"red"})
plt.plot([y_val_inv.min(), y_val_inv.max()], [y_val_inv.min(), y_val_inv.max()], 'k--', lw=2, label='Perfect Prediction')

plt.title(f'R² Regression Plot (TF-MLP-GPU) R² = {r2:.4f}')
plt.xlabel('Actual Values')
plt.ylabel('Predicted Values')
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
model.save(r'../model/MLP_base_model_GPU.keras')

# %%
date_time = df.loc[y_val.index,'DATE_TIME']  


df_forecast = pd.DataFrame({
    "DATE_TIME": date_time,
    "Actual": y_val_inv.flatten(),
    "Predicted": y_pred.flatten()
})


df_forecast["DATE_TIME"] = pd.to_datetime(df_forecast["DATE_TIME"])


mask = (df_forecast["DATE_TIME"].dt.time >= pd.to_datetime("07:00").time()) & \
       (df_forecast["DATE_TIME"].dt.time <= pd.to_datetime("14:00").time())

df_8hr = df_forecast[mask]
df_hourly = df_forecast.iloc[::4]

# %%
plt.figure(figsize=(12, 6))
plt.plot(df_hourly["DATE_TIME"], df_hourly["Actual"], label="Actual", color="blue", linewidth=2)
plt.plot(df_hourly["DATE_TIME"], df_hourly["Predicted"], label="Predicted", color="orange", linestyle="--", linewidth=2)

plt.title("Forecasting Plot: Actual vs Predicted Over Time (Hourly) (TF-MLP-GPU)")
plt.xlabel("Time")
plt.ylabel("Target Variable")
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.xticks(rotation=45)
plt.show()

# %%
plt.figure(figsize=(12, 6))
plt.plot(df_8hr["DATE_TIME"], df_8hr["Actual"], label="Actual", color="blue", linewidth=2)
plt.plot(df_8hr["DATE_TIME"], df_8hr["Predicted"], label="Predicted", color="orange", linestyle="--", linewidth=2)

plt.title("Forecasting Plot: Actual vs Predicted Over Time (8hr) (TF-MLP-GPU)")
plt.xlabel("Time")
plt.ylabel("Target Variable")
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# ## LSTM

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM,Dense,Dropout,LayerNormalization,LeakyReLU
from tensorflow.keras import regularizers
from tensorflow.keras.callbacks import EarlyStopping
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_absolute_error,r2_score,mean_squared_error

# %%
df_lstm = df.copy()

# %%
features = ['AMBIENT_TEMPERATURE', 'IRRADIATION', 'DC_PER_IRR',
       'HOUR_SIN', 'HOUR_COS', 'IS_NIGHT', 'DAWN_DUSK', 
       'IRR_15MIN_AGO', 'TEMP_30MIN_AGO', 'DAY_OF_WEEK', 'IS_WEEKEND']
target = ['DC_POWER']
scale = ['AMBIENT_TEMPERATURE', 'IRRADIATION', 'DC_PER_IRR','IRR_15MIN_AGO', 'TEMP_30MIN_AGO']

# %%
X_to_scale = df_lstm[scale]
X_rest = df_lstm[[col for col in features if col not in scale]]

scaler_x = MinMaxScaler()
X_scaled = pd.DataFrame(scaler_x.fit_transform(X_to_scale), columns=scale, index=df_lstm.index)

X = pd.concat([X_scaled, X_rest], axis=1)[features]

# %%
y = df_lstm[target]

scaler_y = MinMaxScaler()
y_scaled = pd.DataFrame(scaler_y.fit_transform(y),columns=target,index=df_lstm.index)
y = y_scaled

# %%
dump(scaler_x,r'../model/lstm_x_scaler.joblib')
dump(scaler_y,r'../model/lstm_y_scaler.joblib')
# Out:
# ['../model/lstm_y_scaler.joblib']

# %%
train_size = int(len(X) * 0.8)
X_train, X_val = X[:train_size], X[train_size:]
y_train, y_val = y[:train_size], y[train_size:]

# %%
y_train = y_train.to_numpy().reshape(-1, 1)
y_val = y_val.to_numpy().reshape(-1, 1)
X_train = X_train.to_numpy().reshape((X_train.shape[0], 1, X_train.shape[1]))
X_val = X_val.to_numpy().reshape((X_val.shape[0], 1, X_val.shape[1]))

# %%
model = Sequential([
    LSTM(128, return_sequences=True, input_shape=(1, X_train.shape[2]),
          kernel_regularizer=regularizers.L2(0.01)),
    LSTM(64, return_sequences=False),
    Dense(64),
    LeakyReLU(alpha=0.1),
    Dense(32),
    LeakyReLU(alpha=0.1),
    Dense(1)
])
model.compile(optimizer='adam', loss='mae', metrics=['mse'])

# %%
class TimeResourceCallback(tf.keras.callbacks.Callback):
    def on_train_begin(self, logs=None):
        self.epoch_times = []
        self.gpu_memory = []
        self.cpu_memory = []

    def on_epoch_begin(self, epoch, logs=None):
        self.start_time = time.time()

    def on_epoch_end(self, epoch, logs=None):
        # record time
        self.epoch_times.append(time.time() - self.start_time)

        # check GPU
        gpus = GPUtil.getGPUs()
        if gpus:  # GPU mode
            self.gpu_memory.append(gpus[0].memoryUsed)  # in MB
            self.cpu_memory.append(None)
        else:  # CPU mode
            mem = psutil.virtual_memory().used / (1024 ** 2)  # in MB
            self.cpu_memory.append(mem)
            self.gpu_memory.append(None)

# %%
start = time.time()
time_res_cb = TimeResourceCallback()
with tf.device('/GPU:0'):
    history = model.fit(X_train,y_train,validation_data=(X_val, y_val),epochs=100,batch_size=64,shuffle=True,callbacks=[time_res_cb],verbose=1)
end = time.time()
train_time = end - start
# Out:
# Epoch 1/100
# 6/6 [==============================] - 6s 194ms/step - loss: 0.4586 - mse: 0.1828 - val_loss: 0.4092 - val_mse: 0.1481
# Epoch 2/100
# 6/6 [==============================] - 0s 25ms/step - loss: 0.4137 - mse: 0.1634 - val_loss: 0.3643 - val_mse: 0.1305
# Epoch 3/100
# 6/6 [==============================] - 0s 25ms/step - loss: 0.3669 - mse: 0.1426 - val_loss: 0.3148 - val_mse: 0.1031
# Epoch 4/100
# 6/6 [==============================] - 0s 25ms/step - loss: 0.3139 - mse: 0.1047 - val_loss: 0.2548 - val_mse: 0.0630
# Epoch 5/100
# 6/6 [==============================] - 0s 25ms/step - loss: 0.2433 - mse: 0.0553 - val_loss: 0.1889 - val_mse: 0.0202
# Epoch 6/100
# 6/6 [==============================] - 0s 25ms/step - loss: 0.1742 - mse: 0.0167 - val_loss: 0.1600 - val_mse: 0.0127
# Epoch 7/100
# 6/6 [==============================] - 0s 28ms/step - loss: 0.1359 - mse: 0.0076 - val_loss: 0.1152 - val_mse: 0.0045
# Epoch 8/100
# 6/6 [==============================] - 0s 25ms/step - loss: 0.1135 - mse: 0.0046 - val_loss: 0.0911 - val_mse: 0.0018
# Epoch 9/100
# 6/6 [==============================] - 0s 25ms/step - loss: 0.0885 - mse: 0.0021 - val_loss: 0.0785 - val_mse: 0.0013
# Epoch 10/100
# 6/6 [==============================] - 0s 25ms/step - loss: 0.0777 - mse: 0.0017 - val_loss: 0.0708 - val_mse: 0.0011
# Epoch 11/100
# 6/6 [==============================] - 0s 28ms/step - loss: 0.0698 - mse: 0.0016 - val_loss: 0.0647 - val_mse: 0.0012
# Epoch 12/100
# 6/6 [==============================] - 0s 25ms/step - loss: 0.0638 - mse: 0.0016 - val_loss: 0.0613 - val_mse: 0.0015
# Epoch 13/100
# 6/6 [==============================] - 0s 25ms/step - loss: 0.0532 - mse: 9.0206e-04 - val_loss: 0.0506 - val_mse: 9.1430e-04
# Epoch 14/100
# 6/6 [==============================] - 0s 25ms/step - loss: 0.0481 - mse: 8.5917e-04 - val_loss: 0.0481 - val_mse: 9.9488e-04
# Epoch 15/100
# 6/6 [==============================] - 0s 25ms/step - loss: 0.0417 - mse: 5.6257e-04 - val_loss: 0.0399 - val_mse: 5.4127e-04
# Epoch 16/100
# 6/6 [==============================] - 0s 25ms/step - loss: 0.0410 - mse: 6.4062e-04 - val_loss: 0.0388 - val_mse: 5.0874e-04
# Epoch 17/100
# 6/6 [==============================] - 0s 25ms/step - loss: 0.0403 - mse: 7.0036e-04 - val_loss: 0.0366 - val_mse: 5.8123e-04
# Epoch 18/100
# 6/6 [==============================] - 0s 26ms/step - loss: 0.0353 - mse: 4.5668e-04 - val_loss: 0.0376 - val_mse: 8.8339e-04
# Epoch 19/100
# 6/6 [==============================] - 0s 24ms/step - loss: 0.0313 - mse: 3.2067e-04 - val_loss: 0.0351 - val_mse: 6.9891e-04
# Epoch 20/100
# 6/6 [==============================] - 0s 25ms/step - loss: 0.0296 - mse: 3.2964e-04 - val_loss: 0.0284 - val_mse: 3.3018e-04
# Epoch 21/100
# 6/6 [==============================] - 0s 25ms/step - loss: 0.0292 - mse: 3.8128e-04 - val_loss: 0.0290 - val_mse: 4.1880e-04
# Epoch 22/100
# 6/6 [==============================] - 0s 25ms/step - loss: 0.0269 - mse: 2.6269e-04 - val_loss: 0.0291 - val_mse: 5.5618e-04
# Epoch 23/100
# 6/6 [==============================] - 0s 25ms/step - loss: 0.0256 - mse: 2.6030e-04 - val_loss: 0.0254 - val_mse: 2.4803e-04
# Epoch 24/100
# 6/6 [==============================] - 0s 25ms/step - loss: 0.0267 - mse: 3.4782e-04 - val_loss: 0.0286 - val_mse: 5.7706e-04
# Epoch 25/100
# 6/6 [==============================] - 0s 25ms/step - loss: 0.0243 - mse: 2.5792e-04 - val_loss: 0.0267 - val_mse: 4.9683e-04
# Epoch 26/100
# 6/6 [==============================] - 0s 25ms/step - loss: 0.0239 - mse: 2.3230e-04 - val_loss: 0.0235 - val_mse: 2.5552e-04
# Epoch 27/100
# 6/6 [==============================] - 0s 25ms/step - loss: 0.0271 - mse: 4.4896e-04 - val_loss: 0.0233 - val_mse: 2.0182e-04
# Epoch 28/100
# 6/6 [==============================] - 0s 25ms/step - loss: 0.0261 - mse: 4.1802e-04 - val_loss: 0.0293 - val_mse: 8.2165e-04
# Epoch 29/100
# 6/6 [==============================] - 0s 25ms/step - loss: 0.0265 - mse: 5.5999e-04 - val_loss: 0.0243 - val_mse: 3.6858e-04
# Epoch 30/100
# 6/6 [==============================] - 0s 25ms/step - loss: 0.0279 - mse: 6.4116e-04 - val_loss: 0.0236 - val_mse: 3.0814e-04
# Epoch 31/100
# 6/6 [==============================] - 0s 23ms/step - loss: 0.0249 - mse: 4.4111e-04 - val_loss: 0.0232 - val_mse: 3.1143e-04
# Epoch 32/100
# 6/6 [==============================] - 0s 24ms/step - loss: 0.0245 - mse: 4.3155e-04 - val_loss: 0.0215 - val_mse: 2.6112e-04
# Epoch 33/100
# 6/6 [==============================] - 0s 26ms/step - loss: 0.0261 - mse: 6.0185e-04 - val_loss: 0.0223 - val_mse: 2.7448e-04
# Epoch 34/100
# 6/6 [==============================] - 0s 25ms/step - loss: 0.0235 - mse: 3.3666e-04 - val_loss: 0.0216 - val_mse: 3.0049e-04
# Epoch 35/100
# 6/6 [==============================] - 0s 25ms/step - loss: 0.0214 - mse: 2.9867e-04 - val_loss: 0.0212 - val_mse: 3.1268e-04
# Epoch 36/100
# 6/6 [==============================] - 0s 22ms/step - loss: 0.0201 - mse: 2.2664e-04 - val_loss: 0.0198 - val_mse: 2.3511e-04
# Epoch 37/100
# 6/6 [==============================] - 0s 25ms/step - loss: 0.0200 - mse: 2.5361e-04 - val_loss: 0.0214 - val_mse: 3.9725e-04
# Epoch 38/100
# 6/6 [==============================] - 0s 25ms/step - loss: 0.0182 - mse: 1.6689e-04 - val_loss: 0.0194 - val_mse: 2.6338e-04
# Epoch 39/100
# 6/6 [==============================] - 0s 28ms/step - loss: 0.0195 - mse: 2.4421e-04 - val_loss: 0.0180 - val_mse: 1.8257e-04
# Epoch 40/100
# 6/6 [==============================] - 0s 25ms/step - loss: 0.0204 - mse: 2.7234e-04 - val_loss: 0.0216 - val_mse: 4.1303e-04
# Epoch 41/100
# 6/6 [==============================] - 0s 25ms/step - loss: 0.0199 - mse: 2.7513e-04 - val_loss: 0.0307 - val_mse: 0.0011
# Epoch 42/100
# 6/6 [==============================] - 0s 24ms/step - loss: 0.0199 - mse: 2.7297e-04 - val_loss: 0.0251 - val_mse: 6.5697e-04
# Epoch 43/100
# 6/6 [==============================] - 0s 25ms/step - loss: 0.0180 - mse: 1.9423e-04 - val_loss: 0.0189 - val_mse: 2.7863e-04
# Epoch 44/100
# 6/6 [==============================] - 0s 26ms/step - loss: 0.0170 - mse: 1.7395e-04 - val_loss: 0.0173 - val_mse: 2.1657e-04
# Epoch 45/100
# 6/6 [==============================] - 0s 23ms/step - loss: 0.0181 - mse: 2.2741e-04 - val_loss: 0.0182 - val_mse: 2.0808e-04
# Epoch 46/100
# 6/6 [==============================] - 0s 25ms/step - loss: 0.0192 - mse: 2.4505e-04 - val_loss: 0.0203 - val_mse: 3.6296e-04
# Epoch 47/100
# 6/6 [==============================] - 0s 25ms/step - loss: 0.0168 - mse: 1.5752e-04 - val_loss: 0.0300 - val_mse: 0.0011
# Epoch 48/100
# 6/6 [==============================] - 0s 22ms/step - loss: 0.0199 - mse: 3.0900e-04 - val_loss: 0.0284 - val_mse: 8.8958e-04
# Epoch 49/100
# 6/6 [==============================] - 0s 26ms/step - loss: 0.0182 - mse: 2.3993e-04 - val_loss: 0.0181 - val_mse: 2.4548e-04
# Epoch 50/100
# 6/6 [==============================] - 0s 23ms/step - loss: 0.0177 - mse: 2.3977e-04 - val_loss: 0.0165 - val_mse: 2.0140e-04
# Epoch 51/100
# 6/6 [==============================] - 0s 23ms/step - loss: 0.0178 - mse: 2.1846e-04 - val_loss: 0.0177 - val_mse: 2.4774e-04
# Epoch 52/100
# 6/6 [==============================] - 0s 25ms/step - loss: 0.0179 - mse: 2.2964e-04 - val_loss: 0.0186 - val_mse: 2.2939e-04
# Epoch 53/100
# 6/6 [==============================] - 0s 25ms/step - loss: 0.0186 - mse: 3.0104e-04 - val_loss: 0.0163 - val_mse: 1.5710e-04
# Epoch 54/100
# 6/6 [==============================] - 0s 25ms/step - loss: 0.0197 - mse: 3.4266e-04 - val_loss: 0.0175 - val_mse: 2.5626e-04
# Epoch 55/100
# 6/6 [==============================] - 0s 29ms/step - loss: 0.0184 - mse: 3.0100e-04 - val_loss: 0.0161 - val_mse: 2.0772e-04
# Epoch 56/100
# 6/6 [==============================] - 0s 25ms/step - loss: 0.0156 - mse: 1.4852e-04 - val_loss: 0.0198 - val_mse: 3.6068e-04
# Epoch 57/100
# 6/6 [==============================] - 0s 25ms/step - loss: 0.0154 - mse: 1.3025e-04 - val_loss: 0.0194 - val_mse: 3.3664e-04
# Epoch 58/100
# 6/6 [==============================] - 0s 25ms/step - loss: 0.0158 - mse: 1.5618e-04 - val_loss: 0.0171 - val_mse: 1.9569e-04
# Epoch 59/100
# 6/6 [==============================] - 0s 25ms/step - loss: 0.0163 - mse: 1.5856e-04 - val_loss: 0.0199 - val_mse: 3.8166e-04
# Epoch 60/100
# 6/6 [==============================] - 0s 25ms/step - loss: 0.0163 - mse: 1.5572e-04 - val_loss: 0.0154 - val_mse: 1.2938e-04
# Epoch 61/100
# 6/6 [==============================] - 0s 23ms/step - loss: 0.0164 - mse: 1.8601e-04 - val_loss: 0.0166 - val_mse: 2.4667e-04
# Epoch 62/100
# 6/6 [==============================] - 0s 25ms/step - loss: 0.0150 - mse: 1.2126e-04 - val_loss: 0.0158 - val_mse: 1.9533e-04
# Epoch 63/100
# 6/6 [==============================] - 0s 25ms/step - loss: 0.0145 - mse: 1.1880e-04 - val_loss: 0.0200 - val_mse: 3.5992e-04
# Epoch 64/100
# 6/6 [==============================] - 0s 24ms/step - loss: 0.0167 - mse: 2.2247e-04 - val_loss: 0.0255 - val_mse: 8.7658e-04
# Epoch 65/100
# 6/6 [==============================] - 0s 25ms/step - loss: 0.0151 - mse: 1.7651e-04 - val_loss: 0.0209 - val_mse: 4.5731e-04
# Epoch 66/100
# 6/6 [==============================] - 0s 25ms/step - loss: 0.0149 - mse: 1.6904e-04 - val_loss: 0.0135 - val_mse: 1.2158e-04
# Epoch 67/100
# 6/6 [==============================] - 0s 25ms/step - loss: 0.0138 - mse: 1.2412e-04 - val_loss: 0.0153 - val_mse: 2.0813e-04
# Epoch 68/100
# 6/6 [==============================] - 0s 25ms/step - loss: 0.0137 - mse: 1.1519e-04 - val_loss: 0.0178 - val_mse: 3.3219e-04
# Epoch 69/100
# 6/6 [==============================] - 0s 25ms/step - loss: 0.0141 - mse: 1.5368e-04 - val_loss: 0.0135 - val_mse: 1.5041e-04
# Epoch 70/100
# 6/6 [==============================] - 0s 25ms/step - loss: 0.0128 - mse: 1.0194e-04 - val_loss: 0.0184 - val_mse: 3.3270e-04
# Epoch 71/100
# 6/6 [==============================] - 0s 24ms/step - loss: 0.0140 - mse: 1.4276e-04 - val_loss: 0.0141 - val_mse: 1.1619e-04
# Epoch 72/100
# 6/6 [==============================] - 0s 26ms/step - loss: 0.0174 - mse: 3.0910e-04 - val_loss: 0.0136 - val_mse: 1.4777e-04
# Epoch 73/100
# 6/6 [==============================] - 0s 26ms/step - loss: 0.0161 - mse: 2.4475e-04 - val_loss: 0.0222 - val_mse: 5.5578e-04
# Epoch 74/100
# 6/6 [==============================] - 0s 25ms/step - loss: 0.0141 - mse: 1.4192e-04 - val_loss: 0.0132 - val_mse: 1.2080e-04
# Epoch 75/100
# 6/6 [==============================] - 0s 25ms/step - loss: 0.0139 - mse: 1.3009e-04 - val_loss: 0.0129 - val_mse: 1.1333e-04
# Epoch 76/100
# 6/6 [==============================] - 0s 26ms/step - loss: 0.0142 - mse: 1.4240e-04 - val_loss: 0.0150 - val_mse: 2.2359e-04
# Epoch 77/100
# 6/6 [==============================] - 0s 26ms/step - loss: 0.0121 - mse: 8.4872e-05 - val_loss: 0.0129 - val_mse: 1.2638e-04
# Epoch 78/100
# 6/6 [==============================] - 0s 28ms/step - loss: 0.0126 - mse: 1.0419e-04 - val_loss: 0.0161 - val_mse: 2.6187e-04
# Epoch 79/100
# 6/6 [==============================] - 0s 22ms/step - loss: 0.0136 - mse: 1.5197e-04 - val_loss: 0.0121 - val_mse: 1.2152e-04
# Epoch 80/100
# 6/6 [==============================] - 0s 23ms/step - loss: 0.0120 - mse: 8.7485e-05 - val_loss: 0.0131 - val_mse: 1.1820e-04
# Epoch 81/100
# 6/6 [==============================] - 0s 25ms/step - loss: 0.0141 - mse: 1.5495e-04 - val_loss: 0.0130 - val_mse: 1.4212e-04
# Epoch 82/100
# 6/6 [==============================] - 0s 25ms/step - loss: 0.0150 - mse: 2.3033e-04 - val_loss: 0.0200 - val_mse: 4.5756e-04
# Epoch 83/100
# 6/6 [==============================] - 0s 25ms/step - loss: 0.0152 - mse: 2.0589e-04 - val_loss: 0.0121 - val_mse: 9.9563e-05
# Epoch 84/100
# 6/6 [==============================] - 0s 25ms/step - loss: 0.0141 - mse: 1.7438e-04 - val_loss: 0.0121 - val_mse: 1.0386e-04
# Epoch 85/100
# 6/6 [==============================] - 0s 25ms/step - loss: 0.0143 - mse: 1.7433e-04 - val_loss: 0.0171 - val_mse: 2.9923e-04
# Epoch 86/100
# 6/6 [==============================] - 0s 25ms/step - loss: 0.0138 - mse: 1.5720e-04 - val_loss: 0.0124 - val_mse: 8.8623e-05
# Epoch 87/100
# 6/6 [==============================] - 0s 25ms/step - loss: 0.0138 - mse: 1.6908e-04 - val_loss: 0.0123 - val_mse: 1.2364e-04
# Epoch 88/100
# 6/6 [==============================] - 0s 26ms/step - loss: 0.0139 - mse: 1.7018e-04 - val_loss: 0.0182 - val_mse: 3.6238e-04
# Epoch 89/100
# 6/6 [==============================] - 0s 25ms/step - loss: 0.0130 - mse: 1.3186e-04 - val_loss: 0.0119 - val_mse: 8.8857e-05
# Epoch 90/100
# 6/6 [==============================] - 0s 25ms/step - loss: 0.0130 - mse: 1.3832e-04 - val_loss: 0.0112 - val_mse: 7.3535e-05
# Epoch 91/100
# 6/6 [==============================] - 0s 26ms/step - loss: 0.0118 - mse: 8.6563e-05 - val_loss: 0.0117 - val_mse: 9.5633e-05
# Epoch 92/100
# 6/6 [==============================] - 0s 25ms/step - loss: 0.0119 - mse: 1.0552e-04 - val_loss: 0.0224 - val_mse: 5.5464e-04
# Epoch 93/100
# 6/6 [==============================] - 0s 25ms/step - loss: 0.0143 - mse: 1.9170e-04 - val_loss: 0.0155 - val_mse: 2.8290e-04
# Epoch 94/100
# 6/6 [==============================] - 0s 25ms/step - loss: 0.0127 - mse: 1.4328e-04 - val_loss: 0.0115 - val_mse: 9.7203e-05
# Epoch 95/100
# 6/6 [==============================] - 0s 25ms/step - loss: 0.0128 - mse: 1.4251e-04 - val_loss: 0.0146 - val_mse: 2.1665e-04
# Epoch 96/100
# 6/6 [==============================] - 0s 25ms/step - loss: 0.0141 - mse: 2.0924e-04 - val_loss: 0.0117 - val_mse: 8.7253e-05
# Epoch 97/100
# 6/6 [==============================] - 0s 25ms/step - loss: 0.0137 - mse: 1.7139e-04 - val_loss: 0.0111 - val_mse: 8.9494e-05
# Epoch 98/100
# 6/6 [==============================] - 0s 25ms/step - loss: 0.0126 - mse: 1.4534e-04 - val_loss: 0.0208 - val_mse: 5.3671e-04
# Epoch 99/100
# 6/6 [==============================] - 0s 26ms/step - loss: 0.0162 - mse: 2.9661e-04 - val_loss: 0.0229 - val_mse: 7.0318e-04
# Epoch 100/100
# 6/6 [==============================] - 0s 25ms/step - loss: 0.0144 - mse: 2.1053e-04 - val_loss: 0.0163 - val_mse: 3.2488e-04

# %%
epochs = range(1, len(time_res_cb.epoch_times) + 1)

fig, ax1 = plt.subplots()

# Epoch time
ax1.set_xlabel('Epoch')
ax1.set_ylabel('Time (s)', color='tab:blue')
ax1.plot(epochs, time_res_cb.epoch_times, color='tab:blue', marker='o', label="Time per epoch")
ax1.tick_params(axis='y', labelcolor='tab:blue')

# Resource usage
ax2 = ax1.twinx()
ax2.set_ylabel('Memory (MB)', color='tab:red')

if any(time_res_cb.gpu_memory):
    ax2.plot(epochs, time_res_cb.gpu_memory, color='tab:red', marker='x', label="GPU Memory")
else:
    ax2.plot(epochs, time_res_cb.cpu_memory, color='tab:green', marker='x', label="CPU Memory")

ax2.tick_params(axis='y', labelcolor='tab:red')
plt.title("Training Time & Resource Usage per Epoch (TF-LSTM-GPU)")
fig.tight_layout()
plt.show()

# %%
y_pred_scaled = np.clip(model.predict(X_val), 0, None) 
y_pred = scaler_y.inverse_transform(y_pred_scaled)
y_val_inv = scaler_y.inverse_transform(y_val)


print(f"MAE: {mean_absolute_error(y_val_inv, y_pred):.4f}")
print(f"RMSE: {np.sqrt(mean_squared_error(y_val_inv, y_pred)):.4f}")
print(f"R²: {r2_score(y_val_inv, y_pred):.4f}")
print(f"Training time: {train_time:.2f} seconds")
# Out:
# 3/3 [==============================] - 1s 5ms/step
# MAE: 0.2269
# RMSE: 0.3805
# R²: 0.9969
# Training time: 20.26 seconds

# %%
plt.figure(figsize=(8,6))
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title('Learning Curve (TF-LSTM-GPU)')
plt.legend()
plt.show()

# %%
model.save(r'../model/LSTM_model_GPU.keras')

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(12,6))
plt.plot(y_val_inv, label='Actual')
plt.plot(y_pred, label='Predicted')
plt.title("LSTM Forecast vs Actual (TF-LSTM-GPU)")
plt.legend()
plt.grid(True)
plt.show()

# %%
r2 = r2_score(y_val_inv, y_pred)

plt.figure(figsize=(8, 6))
sns.regplot(x=y_val_inv.flatten(), y=y_pred.flatten(), scatter_kws={"alpha":0.5, "s": 20}, line_kws={"color":"red"})
plt.plot([y_val_inv.min(), y_val_inv.max()], [y_val_inv.min(), y_val_inv.max()], 'k--', lw=2, label='Perfect Prediction')

plt.title(f'R² Regression Plot (TF-LSTM-GPU) R² = {r2:.4f}')
plt.xlabel('Actual Values')
plt.ylabel('Predicted Values')
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
# Extract DATE_TIME column before converting to numpy
date_time = df["DATE_TIME"]

# Manual split
train_size = int(len(X) * 0.8)
X_train, X_val = X[:train_size], X[train_size:]
y_train, y_val = y[:train_size], y[train_size:]
dt_train, dt_val = date_time[:train_size], date_time[train_size:]

# Convert to NumPy arrays
y_train = y_train.to_numpy().reshape(-1, 1)
y_val = y_val.to_numpy().reshape(-1, 1)
X_train = X_train.to_numpy().reshape((X_train.shape[0], 1, X_train.shape[1]))
X_val = X_val.to_numpy().reshape((X_val.shape[0], 1, X_val.shape[1]))
  


df_forecast = pd.DataFrame({
    "DATE_TIME": dt_val.reset_index(drop=True),
    "Actual": y_val_inv.flatten(),
    "Predicted": y_pred.flatten()
})

df_forecast["DATE_TIME"] = pd.to_datetime(df_forecast["DATE_TIME"])  

mask = (df_forecast["DATE_TIME"].dt.time >= pd.to_datetime("07:00").time()) & \
       (df_forecast["DATE_TIME"].dt.time <= pd.to_datetime("14:00").time())

df_8hr = df_forecast[mask]
df_hourly = df_forecast.iloc[::4]

# %%
plt.figure(figsize=(12, 6))
plt.plot(df_hourly["DATE_TIME"], df_hourly["Actual"], label="Actual", color="blue", linewidth=2)
plt.plot(df_hourly["DATE_TIME"], df_hourly["Predicted"], label="Predicted", color="orange", linestyle="--", linewidth=2)

plt.title("Forecasting Plot: Actual vs Predicted Over Time (Hourly) (TF-LSTM-GPU)")
plt.xlabel("Time")
plt.ylabel("Target Variable")
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.xticks(rotation=45)
plt.show()

# %%
plt.figure(figsize=(12, 6))
plt.plot(df_8hr["DATE_TIME"], df_8hr["Actual"], label="Actual", color="blue", linewidth=2)
plt.plot(df_8hr["DATE_TIME"], df_8hr["Predicted"], label="Predicted", color="orange", linestyle="--", linewidth=2)

plt.title("Forecasting Plot: Actual vs Predicted Over Time (8hr)\n (TF-LSTM-GPU)")
plt.xlabel("Time")
plt.ylabel("Target Variable")
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.xticks(rotation=45)
plt.show()
